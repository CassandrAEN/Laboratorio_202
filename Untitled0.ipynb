# %% [markdown]
# <a href="https://colab.research.google.com/github/CassandrAEN/Laboratorio_102/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #verificar lectura de archivo CSV

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
path="/content/drive/MyDrive/conjunto de daros/atenciones_abogadas_de_las_mujeres.csv"

df= pd.read_csv(path)

registros = df.shape[0]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-4-ded70c83c491>:7: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv(path)

# %% [markdown]
# #Hacer uso de la funcion info()

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
path="/content/drive/MyDrive/conjunto de daros/atenciones_abogadas_de_las_mujeres.csv"

df = pd.read_csv(path)

df.info()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-5-333a3546f36d>:7: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121995 entries, 0 to 121994
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   fecha                       121995 non-null  object
#  1   agencia                     120918 non-null  object
#  2   usuaria_sexo                121591 non-null  object
#  3   usuaria_nacionalidad        121641 non-null  object
#  4   usuaria_ent_fed_nacimiento  119967 non-null  object
#  5   usuaria_estado_civil        88051 non-null   object
#  6   usuaria_edad                120005 non-null  float64
# ...

# %% [markdown]
# # Hacer uso de la funcion tall()

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

path ="/content/drive/MyDrive/conjunto de daros/atenciones_abogadas_de_las_mujeres.csv"

df = pd.read_csv(path)

df.tail(1)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-7-0b84049f5821>:8: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
#              fecha agencia usuaria_sexo usuaria_nacionalidad  \
# 121994  2022-03-01   COY-5        MUJER             MEXICANA
#
#              usuaria_ent_fed_nacimiento usuaria_estado_civil  usuaria_edad  \
# 121994  VERACRUZ DE IGNACIO DE LA LLAVE           SOLTERA(O)          31.0
#
#         usuaria_hijas  usuaria_hijos  usuaria_hijes  ... riesgo_feminicida  \
# 121994            0.0            0.0            0.0  ...                NO
#
#        vio_psicoemocional vio_fisica vio_economica vio_patrimonial vio_sexual  \
# 121994                 Sí         Sí            No              Sí         No
#
#        vio_simbolica vio_obstetrica vio_reproductivos vio_feminicida
# ...

# %% [markdown]
# # Obtener el rango de fechas

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

path ="/content/drive/MyDrive/conjunto de daros/atenciones_abogadas_de_las_mujeres.csv"

df =pd.read_csv(path)

df["fecha"] = pd.to_datetime(df["fecha"], format="%Y-%m-%d")

fecha_inicial = df["fecha"].min()

fecha_final = df["fecha"].max()

print(f"El rango de fecha es del {fecha_inicial} al {fecha_final}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# El rango de fecha es del 2019-03-01 00:00:00 al 2022-03-01 00:00:00
# <ipython-input-9-d16c25f862b0>:8: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv(path)

# %% [markdown]
# # Obtener la medida aritmetica

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import matplotlib.pyplot as plt

path ="/content/drive/MyDrive/conjunto de daros/atenciones_abogadas_de_las_mujeres.csv"

df= pd.read_csv(path)

media = df["usuaria_edad"].mean()

print(media)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 38.38658389233782
# <ipython-input-10-498c498b8862>:9: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv(path)

# %% [markdown]
# # Obtener la moda

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import matplotlib.pyplot as plt

path ="/content/drive/MyDrive/conjunto de daros/atenciones_abogadas_de_las_mujeres.csv"

df = pd.read_csv(path)
moda = df["usuaria_edad"].mode()

print(moda)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 0    30.0
# Name: usuaria_edad, dtype: float64
# <ipython-input-13-3734da4892ea>:9: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
