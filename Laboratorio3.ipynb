# %% [markdown]
# <a href="https://colab.research.google.com/github/CassandrAEN/Laboratorio_102/blob/main/Laboratorio3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar libreria pandas y matploitlib
import pandas as pd
import matplotlib.pyplot as plt

# Obtener url de archivo csv
path="/atenciones_abogadas_de_las_mujeres (1).csv"

# Leer el CSV
df=pd.read_csv(path)

# Obtener la serie de datos df["usuaria_edad"]
edad=df["usuaria_edad"]
# Crear la distribución
dist=edad.value_counts()
# Crear el gráfico
plt.bar(dist.index, dist.values)
# Ajustar el eje x
plt.xlim(0, 100)
# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-1-68f85a305626>:9: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Obtener el url de archivo csv
path="/atenciones_abogadas_de_las_mujeres (1).csv"

# Leer el CSV
df= pd.read_csv(path)

# Obtener el conteo de cada categoría
conteo= df["usuaria_estado_civil"].value_counts()

# Crear el diagrama de barras
plt.barh(conteo.index, conteo)

# Graficar
plt.show()
# Out:
# <ipython-input-7-6c927d8b511c>:8: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Obtener url de archivo csv
path="/atenciones_abogadas_de_las_mujeres (1).csv"

# Leer CSV
df=pd.read_csv(path)

# Obtener el conteo de cada categoría
conteo=df["usuaria_estado_civil"].value_counts()

#Crear el diagrama de barras
plt.barh(conteo.index, conteo)

# Graficar
plt.show()
# Out:
# <ipython-input-10-56ae7c08c782>:8: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt

path="/atenciones_abogadas_de_las_mujeres (1).csv"

# Crear un dataframe
df= pd.read_csv(path)

# Filtrado
df_filtrado=df.query("usuaria_edad<=160")
print(df_filtrado["usuaria_edad"])

# Crear el diagrama de caja
plt.boxplot(df_filtrado["usuaria_edad"])

# Mostrar el diagrama de caja
plt.show()
# Out:
# <ipython-input-12-e31bf36e99f0>:7: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv(path)
# 0         33.0
# 1         26.0
# 2         25.0
# 3         55.0
# 4         33.0
#           ...
# 121990    50.0
# 121991    31.0
# 121992    20.0
# 121993    26.0
# 121994    31.0
# Name: usuaria_edad, Length: 119978, dtype: float64
