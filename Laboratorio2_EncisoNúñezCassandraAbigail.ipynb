# %% [markdown]
# <a href="https://colab.research.google.com/github/CassandrAEN/Laboratorio_102/blob/main/Laboratorio2_EncisoN%C3%BA%C3%B1ezCassandraAbigail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Verificar lectura de archivo CSV

# %%
# Importar libreria pandas
import pandas as pd

# Obtener url de archivo csv
path="/atenciones_abogadas_de_las_mujeres.csv"

# Leer el CSV
df=pd.read_csv(path)
# Obtener el número de registros
registros=df.shape[0]

# Imprimir el número de registros
print(registros)
# Out:
# 121995
# <ipython-input-5-a145748d7f69>:8: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)

# %% [markdown]
# # Hacer uso de la función info()

# %%
# Importar libreria pandas
import pandas as pd

# Obtener el url de archivo csv
path="/atenciones_abogadas_de_las_mujeres.csv"

# Leer el CSV
df=pd.read_csv(path)

df.info()
# Out:
# <ipython-input-6-21d8c54fe395>:8: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121995 entries, 0 to 121994
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   fecha                       121995 non-null  object
#  1   agencia                     120918 non-null  object
#  2   usuaria_sexo                121591 non-null  object
#  3   usuaria_nacionalidad        121641 non-null  object
#  4   usuaria_ent_fed_nacimiento  119967 non-null  object
#  5   usuaria_estado_civil        88051 non-null   object
#  6   usuaria_edad                120005 non-null  float64
#  7   usuaria_hijas               108979 non-null  float64
#  8   usuaria_hijos               102770 non-null  float64
#  9   usuaria_hijes               108646 non-null  float64
# ...

# %% [markdown]
# # Hacer uso de la función tail()

# %%
# Importar libreria pandas
import pandas as pd

# Obtener url de archivo csv
path="/atenciones_abogadas_de_las_mujeres.csv"

# Leer el CSV
df=pd.read_csv(path)

df.tail(1)
# Out:
# <ipython-input-3-070f6acc55a1>:8: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)
#              fecha agencia usuaria_sexo usuaria_nacionalidad  \
# 121994  2022-03-01   COY-5        MUJER             MEXICANA
#
#              usuaria_ent_fed_nacimiento usuaria_estado_civil  usuaria_edad  \
# 121994  VERACRUZ DE IGNACIO DE LA LLAVE           SOLTERA(O)          31.0
#
#         usuaria_hijas  usuaria_hijos  usuaria_hijes  ... riesgo_feminicida  \
# 121994            0.0            0.0            0.0  ...                NO
#
#        vio_psicoemocional vio_fisica vio_economica vio_patrimonial vio_sexual  \
# 121994                 Sí         Sí            No              Sí         No
#
#        vio_simbolica vio_obstetrica vio_reproductivos vio_feminicida
# 121994            No             No                No             No
#
# [1 rows x 28 columns]

# %% [markdown]
# # Obtener el rango de fechas

# %%
# Importar libreria pandas
import pandas as pd

# Obtener url de archivo csv
path="/atenciones_abogadas_de_las_mujeres.csv"

# Leer el CSV
df=pd.read_csv(path)

# Dar formato de fecha
df["fecha"]=pd.to_datetime(df["fecha"], format="%Y-%m-%d")

# Obtener el rango de fecha minimo
fecha_inicial= df["fecha"].min()

# Obtener el rango de fecha maximo
fecha_final= df["fecha"].max()

# Imprimir rango de fecha
print(f"El rango de fecha es del {fecha_inicial} al {fecha_final}")
# Out:
# El rango de fecha es del 2019-03-01 00:00:00 al 2022-03-01 00:00:00
# <ipython-input-21-80693e6864ae>:8: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)

# %% [markdown]
# # Obtener la media aritmética

# %%
# Importar libreria pandas y matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Obtener url de archivo csv
path="/atenciones_abogadas_de_las_mujeres.csv"

# Leer el CSV
df=pd.read_csv(path)

# Obtener la media
media=df["usuaria_edad"].mean()

# Imprimir la media
print(media)
# Out:
# 38.38658389233782
# <ipython-input-22-9f71cd4eac12>:9: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)

# %% [markdown]
# # Obtener la moda

# %%
# Importar libreria pandas y matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Obtener url de archivo csv
path="/atenciones_abogadas_de_las_mujeres.csv"

# Leer el CSV
df=pd.read_csv(path)

# Obtener la moda
moda=df["usuaria_edad"].mode()

# Imprimir
print(moda)
# Out:
# 0    30.0
# Name: usuaria_edad, dtype: float64
# <ipython-input-25-217994fcbd34>:9: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)
